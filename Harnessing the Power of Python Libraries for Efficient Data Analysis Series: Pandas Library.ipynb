# %% [markdown]
# <a href="https://colab.research.google.com/github/AarifSheikh-78603/Internship-2024-25/blob/main/Harnessing%20the%20Power%20of%20Python%20Libraries%20for%20Efficient%20Data%20Analysis%20Series%3A%20Pandas%20Library.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
# Creating a Series
s = pd.Series([1, 3, 5, 7, 9])
print(s)
# Out:
# 0    1
# 1    3
# 2    5
# 3    7
# 4    9
# dtype: int64

# %%
# Creating a DataFrame from a dictionary
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David'],
    'Age': [24, 27, 22, 32],
    'City': ['New York', 'Los Angeles', 'Chicago', 'Houston']
}
df = pd.DataFrame(data)
print(df)
# Out:
#       Name  Age         City
# 0    Alice   24     New York
# 1      Bob   27  Los Angeles
# 2  Charlie   22      Chicago
# 3    David   32      Houston

# %% [markdown]
# ## Read Excel Data File

# %%
Data = pd.read_excel('Pandas Emp.xlsx')

# %% [markdown]
# ## Read CSV File

# %%
df = pd.read_csv('Top 10 (Most Runs).csv')

# %%
df = pd.read_csv('Pandas Emp.csv', encoding='latin')

# %%
df = pd.read_csv('Pandas Emp-1.csv', encoding='latin')

# %%
df = pd.read_csv('Pandas Emp-2.csv', encoding='latin')

# %%
df = pd.read_csv('Top 10 (Most Runs).csv')

# %% [markdown]
# # Inspectin Data

# %%
df.head()
# Out:
#                      Player       Span  Mat  Inns  NO   BF  Runs  0  4s  6s  \
# 0  Rahmanullah Gurbaz (AFG)  2024-2024    8     8   0  226   281  2  18  16
# 1           RG Sharma (IND)  2024-2024    8     8   1  164   257  0  24  15
# 2             TM Head (AUS)  2024-2024    7     7   1  161   255  1  26  15
# 3            Q de Kock (SA)  2024-2024    9     9   0  173   243  1  21  13
# 4      Ibrahim Zadran (AFG)  2024-2024    8     8   0  215   231  1  25   4
#
#    50  100  HS    Ave      SR
# 0   3    0  80  35.12  124.33
# 1   3    0  92  36.71  156.70
# 2   2    0  76  42.50  158.38
# 3   2    0  74  27.00  140.46
# 4   2    0  70  28.87  107.44

# %%
df.head(10)
# Out:
#                      Player       Span  Mat  Inns  NO   BF  Runs  0  4s  6s  \
# 0  Rahmanullah Gurbaz (AFG)  2024-2024    8     8   0  226   281  2  18  16
# 1           RG Sharma (IND)  2024-2024    8     8   1  164   257  0  24  15
# 2             TM Head (AUS)  2024-2024    7     7   1  161   255  1  26  15
# 3            Q de Kock (SA)  2024-2024    9     9   0  173   243  1  21  13
# 4      Ibrahim Zadran (AFG)  2024-2024    8     8   0  215   231  1  25   4
# 5             N Pooran (WI)  2024-2024    7     7   1  156   228  0  15  17
# 6            AGS Gous (USA)  2024-2024    6     6   1  145   219  0  20  11
# 7          JC Buttler (ENG)  2024-2024    8     7   2  135   214  1  22  10
# 8            SA Yadav (IND)  2024-2024    8     8   1  147   199  0  15  10
#
#    50  100  HS    Ave      SR
# 0   3    0  80  35.12  124.33
# 1   3    0  92  36.71  156.70
# 2   2    0  76  42.50  158.38
# 3   2    0  74  27.00  140.46
# 4   2    0  70  28.87  107.44
# ...

# %%
df.tail()
# Out:
#                  Player       Span  Mat  Inns  NO   BF  Runs  0  4s  6s  50  \
# 4  Ibrahim Zadran (AFG)  2024-2024    8     8   0  215   231  1  25   4   2
# 5         N Pooran (WI)  2024-2024    7     7   1  156   228  0  15  17   1
# 6        AGS Gous (USA)  2024-2024    6     6   1  145   219  0  20  11   2
# 7      JC Buttler (ENG)  2024-2024    8     7   2  135   214  1  22  10   1
# 8        SA Yadav (IND)  2024-2024    8     8   1  147   199  0  15  10   2
#
#    100  HS    Ave      SR
# 4    0  70  28.87  107.44
# 5    0  98  38.00  146.15
# 6    0  80  43.80  151.03
# 7    0  83  42.80  158.51
# 8    0  53  28.42  135.37

# %%
df.tail(10)
# Out:
#                      Player       Span  Mat  Inns  NO   BF  Runs  0  4s  6s  \
# 0  Rahmanullah Gurbaz (AFG)  2024-2024    8     8   0  226   281  2  18  16
# 1           RG Sharma (IND)  2024-2024    8     8   1  164   257  0  24  15
# 2             TM Head (AUS)  2024-2024    7     7   1  161   255  1  26  15
# 3            Q de Kock (SA)  2024-2024    9     9   0  173   243  1  21  13
# 4      Ibrahim Zadran (AFG)  2024-2024    8     8   0  215   231  1  25   4
# 5             N Pooran (WI)  2024-2024    7     7   1  156   228  0  15  17
# 6            AGS Gous (USA)  2024-2024    6     6   1  145   219  0  20  11
# 7          JC Buttler (ENG)  2024-2024    8     7   2  135   214  1  22  10
# 8            SA Yadav (IND)  2024-2024    8     8   1  147   199  0  15  10
#
#    50  100  HS    Ave      SR
# 0   3    0  80  35.12  124.33
# 1   3    0  92  36.71  156.70
# 2   2    0  76  42.50  158.38
# 3   2    0  74  27.00  140.46
# 4   2    0  70  28.87  107.44
# ...

# %%
df.shape
# Out:
# (9, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 15 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Player  9 non-null      object
#  1   Span    9 non-null      object
#  2   Mat     9 non-null      int64
#  3   Inns    9 non-null      int64
#  4   NO      9 non-null      int64
#  5   BF      9 non-null      int64
#  6   Runs    9 non-null      int64
#  7   0       9 non-null      int64
#  8   4s      9 non-null      int64
#  9   6s      9 non-null      int64
#  10  50      9 non-null      int64
#  11  100     9 non-null      int64
#  12  HS      9 non-null      int64
#  13  Ave     9 non-null      float64
#  14  SR      9 non-null      float64
# dtypes: float64(2), int64(11), object(2)
# memory usage: 1.2+ KB

# %%
df.describe()
# Out:
#             Mat      Inns        NO          BF        Runs         0  \
# count  9.000000  9.000000  9.000000    9.000000    9.000000  9.000000
# mean   7.666667  7.555556  0.777778  169.111111  236.333333  0.666667
# std    0.866025  0.881917  0.666667   31.334663   25.263610  0.707107
# min    6.000000  6.000000  0.000000  135.000000  199.000000  0.000000
# 25%    7.000000  7.000000  0.000000  147.000000  219.000000  0.000000
# 50%    8.000000  8.000000  1.000000  161.000000  231.000000  1.000000
# 75%    8.000000  8.000000  1.000000  173.000000  255.000000  1.000000
# max    9.000000  9.000000  2.000000  226.000000  281.000000  2.000000
#
#               4s         6s        50  100         HS        Ave          SR
# count   9.000000   9.000000  9.000000  9.0   9.000000   9.000000    9.000000
# mean   20.666667  12.333333  2.000000  0.0  78.444444  35.913333  142.041111
# std     4.062019   4.062019  0.707107  0.0  12.923923   6.555858   17.351778
# ...

# %%
df['Player']
# Out:
# 0    Rahmanullah Gurbaz (AFG)
# 1             RG Sharma (IND)
# 2               TM Head (AUS)
# 3              Q de Kock (SA)
# 4        Ibrahim Zadran (AFG)
# 5               N Pooran (WI)
# 6              AGS Gous (USA)
# 7            JC Buttler (ENG)
# 8              SA Yadav (IND)
# Name: Player, dtype: object

# %%
df['Player'].sort_values(ascending=True)
# Out:
# 6              AGS Gous (USA)
# 4        Ibrahim Zadran (AFG)
# 7            JC Buttler (ENG)
# 5               N Pooran (WI)
# 3              Q de Kock (SA)
# 1             RG Sharma (IND)
# 0    Rahmanullah Gurbaz (AFG)
# 8              SA Yadav (IND)
# 2               TM Head (AUS)
# Name: Player, dtype: object

# %%
df['Player'].sort_values(ascending=False)
# Out:
# 2               TM Head (AUS)
# 8              SA Yadav (IND)
# 0    Rahmanullah Gurbaz (AFG)
# 1             RG Sharma (IND)
# 3              Q de Kock (SA)
# 5               N Pooran (WI)
# 7            JC Buttler (ENG)
# 4        Ibrahim Zadran (AFG)
# 6              AGS Gous (USA)
# Name: Player, dtype: object

# %%
df[['Player','Runs']].head(10)
# Out:
#                      Player  Runs
# 0  Rahmanullah Gurbaz (AFG)   281
# 1           RG Sharma (IND)   257
# 2             TM Head (AUS)   255
# 3            Q de Kock (SA)   243
# 4      Ibrahim Zadran (AFG)   231
# 5             N Pooran (WI)   228
# 6            AGS Gous (USA)   219
# 7          JC Buttler (ENG)   214
# 8            SA Yadav (IND)   199

# %% [markdown]
# # Filtering Data

# %%
df[df['Runs']>200]
# Out:
#                      Player       Span  Mat  Inns  NO   BF  Runs  0  4s  6s  \
# 0  Rahmanullah Gurbaz (AFG)  2024-2024    8     8   0  226   281  2  18  16
# 1           RG Sharma (IND)  2024-2024    8     8   1  164   257  0  24  15
# 2             TM Head (AUS)  2024-2024    7     7   1  161   255  1  26  15
# 3            Q de Kock (SA)  2024-2024    9     9   0  173   243  1  21  13
# 4      Ibrahim Zadran (AFG)  2024-2024    8     8   0  215   231  1  25   4
# 5             N Pooran (WI)  2024-2024    7     7   1  156   228  0  15  17
# 6            AGS Gous (USA)  2024-2024    6     6   1  145   219  0  20  11
# 7          JC Buttler (ENG)  2024-2024    8     7   2  135   214  1  22  10
#
#    50  100  HS    Ave      SR
# 0   3    0  80  35.12  124.33
# 1   3    0  92  36.71  156.70
# 2   2    0  76  42.50  158.38
# 3   2    0  74  27.00  140.46
# 4   2    0  70  28.87  107.44
# 5   1    0  98  38.00  146.15
# 6   2    0  80  43.80  151.03
# 7   1    0  83  42.80  158.51

# %% [markdown]
# # Dealing with Duplicate Values

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.tail()
# Out:
#                  Player       Span  Mat  Inns  NO   BF  Runs  0  4s  6s  50  \
# 4  Ibrahim Zadran (AFG)  2024-2024    8     8   0  215   231  1  25   4   2
# 5         N Pooran (WI)  2024-2024    7     7   1  156   228  0  15  17   1
# 6        AGS Gous (USA)  2024-2024    6     6   1  145   219  0  20  11   2
# 7      JC Buttler (ENG)  2024-2024    8     7   2  135   214  1  22  10   1
# 8        SA Yadav (IND)  2024-2024    8     8   1  147   199  0  15  10   2
#
#    100  HS    Ave      SR
# 4    0  70  28.87  107.44
# 5    0  98  38.00  146.15
# 6    0  80  43.80  151.03
# 7    0  83  42.80  158.51
# 8    0  53  28.42  135.37

# %%
df.drop_duplicates(inplace=True)

# %%
df.tail()
# Out:
#                  Player       Span  Mat  Inns  NO   BF  Runs  0  4s  6s  50  \
# 4  Ibrahim Zadran (AFG)  2024-2024    8     8   0  215   231  1  25   4   2
# 5         N Pooran (WI)  2024-2024    7     7   1  156   228  0  15  17   1
# 6        AGS Gous (USA)  2024-2024    6     6   1  145   219  0  20  11   2
# 7      JC Buttler (ENG)  2024-2024    8     7   2  135   214  1  22  10   1
# 8        SA Yadav (IND)  2024-2024    8     8   1  147   199  0  15  10   2
#
#    100  HS    Ave      SR
# 4    0  70  28.87  107.44
# 5    0  98  38.00  146.15
# 6    0  80  43.80  151.03
# 7    0  83  42.80  158.51
# 8    0  53  28.42  135.37

# %% [markdown]
# # Handling Missind

# %%
df.isnull()
# Out:
#    Player   Span    Mat   Inns     NO     BF   Runs      0     4s     6s  \
# 0   False  False  False  False  False  False  False  False  False  False
# 1   False  False  False  False  False  False  False  False  False  False
# 2   False  False  False  False  False  False  False  False  False  False
# 3   False  False  False  False  False  False  False  False  False  False
# 4   False  False  False  False  False  False  False  False  False  False
# 5   False  False  False  False  False  False  False  False  False  False
# 6   False  False  False  False  False  False  False  False  False  False
# 7   False  False  False  False  False  False  False  False  False  False
# 8   False  False  False  False  False  False  False  False  False  False
#
#       50    100     HS    Ave     SR
# 0  False  False  False  False  False
# 1  False  False  False  False  False
# 2  False  False  False  False  False
# 3  False  False  False  False  False
# 4  False  False  False  False  False
# ...

# %%
df.isnull().sum()
# Out:
# Player    0
# Span      0
# Mat       0
# Inns      0
# NO        0
# BF        0
# Runs      0
# 0         0
# 4s        0
# 6s        0
# 50        0
# 100       0
# HS        0
# Ave       0
# SR        0
# dtype: int64

# %%
df['NO'].fillna(0, inplace=True)

# %%
df.isnull().sum()
# Out:
# Player    0
# Span      0
# Mat       0
# Inns      0
# NO        0
# BF        0
# Runs      0
# 0         0
# 4s        0
# 6s        0
# 50        0
# 100       0
# HS        0
# Ave       0
# SR        0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Player    0
# Span      0
# Mat       0
# Inns      0
# NO        0
# BF        0
# Runs      0
# 0         0
# 4s        0
# 6s        0
# 50        0
# 100       0
# HS        0
# Ave       0
# SR        0
# dtype: int64
