# %% [markdown]
# <a href="https://colab.research.google.com/github/AarifSheikh-78603/Internship-2024-25/blob/main/Exploring%20the%20Deals%20%26%20Investments%20of%20Shark%20Ashneer%20Grover.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exploratory Data Analysis (EDA) on Shark Tank India using Python
# # Exploring the Deals & Investments of Shark - Ashneer Grover

# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

import plotly.graph_objects as go
import plotly.express as px  # Import plotly.express

# %% [markdown]
# ## Import Dataset

# %%
df = pd.read_csv('Shark Tank India.csv')

# %% [markdown]
# ## Breakdown of Pitches, Present Days, and Investments season by season of Shark - Ashneer Grover

# %%
# Filter out investments where the amount is greater than 0
df_invested = df[df['Ashneer Investment Amount'] > 0]

# Calculate the total number of pitches per season
pitches = df.groupby('Season').size()

# Calculate the total present days per season
present_days = df.groupby('Season')['Ashneer Present'].sum()

# Calculate the total number of investments per season (where investment amount > 0)
investments = df_invested.groupby('Season').size()

# Create a DataFrame with the required values
data = pd.DataFrame({
    'Total Pitches': pitches,
    'Total Present Days': present_days,
    'Total Investments': investments
})

# Plotting
fig, ax = plt.subplots(figsize=(8, 4))

# Plot the Total Pitches bar
pitches_bar = ax.bar(data.index, data['Total Pitches'], label='Total Pitches', color='#CAF0F8', edgecolor='black', linewidth=0.2)

# Plot the Total Present Days bar within the Total Pitches bar
present_days_bar = ax.bar(data.index, data['Total Present Days'], label='Total Present Days', color='#90E0EF', edgecolor='black', linewidth=0.2)

# Plot the Total Investments bar within the Total Present Days bar
investments_bar = ax.bar(data.index, data['Total Investments'], label='Offered Investments', color='#00B4D8', edgecolor='black', linewidth=0.2)

# Add labels and title
ax.set_xlabel('Season')
ax.set_ylabel('Pitches')
ax.set_title('Pitches, Attendance & Investments by Season of Shark - Ashneer Grover', color='r', fontsize=12, fontstyle='oblique')

# Setting yticks to integer values
ymax = 240
plt.yticks(np.arange(0, ymax + 1, step=40))  # Adjust the step value as needed

# Set x-ticks to integer values
ax.set_xticks(data.index)
ax.set_xticklabels(data.index)

plt.grid(linestyle='-', linewidth=0.3, axis='y')

# Show legend
ax.legend(loc='upper right')

# Adding actual values to each stack
for container in ax.containers:
    ax.bar_label(container, label_type='edge', fontstyle='oblique', fontsize=11, color='black')

# Display the plot
plt.show()

# %% [markdown]
# ## % of Attendance (Season 1)

# %%
# Filter out investments where the amount is greater than 0
df_invested = df[df['Ashneer Investment Amount'] > 0]

# Calculate the total number of pitches per season
pitches = df.groupby('Season').size()

# Calculate the total present days per season
present_days = df.groupby('Season')['Ashneer Present'].sum()

# Calculate the total number of investments per season (where investment amount > 0)
investments = df_invested.groupby('Season').size()

# Create a DataFrame with the required values
data = pd.DataFrame({
    'Total Pitches': pitches,
    'Total Present Days': present_days,
    'Total Investments': investments
})

# Extract data for Season 1
season_1_data = data.loc[1]

# Prepare data for pie chart
labels = [
    f'Present: {season_1_data["Total Present Days"]} ({season_1_data["Total Present Days"]/season_1_data["Total Pitches"]*100:.0f}%)',
    f'Absent: {season_1_data["Total Pitches"] - season_1_data["Total Present Days"]} ({(season_1_data["Total Pitches"] - season_1_data["Total Present Days"])/season_1_data["Total Pitches"]*100:.0f}%)'
]
sizes = [season_1_data['Total Present Days'], season_1_data['Total Pitches'] - season_1_data['Total Present Days']]
colors = ['orange', 'lightgrey']

# Plotting the pie chart
fig, ax = plt.subplots(figsize=(4, 4))
ax.pie(sizes, labels=labels, colors=colors, autopct='%1.0f%%', wedgeprops=dict(width=0.6), startangle=0)

# Add title
ax.set_title('Attendance Report (Season 1)')

# Display the pie chart
plt.show()

# %% [markdown]
# ## % of Attendance (Season 2)

# %%
# Filter out investments where the amount is greater than 0
df_invested = df[df['Ashneer Investment Amount'] > 0]

# Calculate the total number of pitches per season
pitches = df.groupby('Season').size()

# Calculate the total present days per season
present_days = df.groupby('Season')['Ashneer Present'].sum()

# Calculate the total number of investments per season (where investment amount > 0)
investments = df_invested.groupby('Season').size()

# Create a DataFrame with the required values
data = pd.DataFrame({
    'Total Pitches': pitches,
    'Total Present Days': present_days,
    'Total Investments': investments
})

# Extract data for Season 2
season_2_data = data.loc[2]

# Prepare data for pie chart
labels = [
    f'Present: {season_2_data["Total Present Days"]} ({season_2_data["Total Present Days"]/season_2_data["Total Pitches"]*100:.0f}%)',
    f'Absent: {season_2_data["Total Pitches"] - season_2_data["Total Present Days"]} ({(season_2_data["Total Pitches"] - season_2_data["Total Present Days"])/season_2_data["Total Pitches"]*100:.0f}%)'
]
sizes = [season_2_data['Total Present Days'], season_2_data['Total Pitches'] - season_2_data['Total Present Days']]
colors = ['orange', 'lightgrey']

# Plotting the pie chart
fig, ax = plt.subplots(figsize=(4, 4))
ax.pie(sizes, labels=labels, colors=colors, autopct='%1.0f%%', wedgeprops=dict(width=0.6), startangle=60)

# Add title
ax.set_title('Attendance Report (Season 2)')

# Display the pie chart
plt.show()

# %% [markdown]
# ## % of Attendance (Season 3)

# %%
# Filter out investments where the amount is greater than 0
df_invested = df[df['Ashneer Investment Amount'] > 0]

# Calculate the total number of pitches per season
pitches = df.groupby('Season').size()

# Calculate the total present days per season
present_days = df.groupby('Season')['Ashneer Present'].sum()

# Calculate the total number of investments per season (where investment amount > 0)
investments = df_invested.groupby('Season').size()

# Create a DataFrame with the required values
data = pd.DataFrame({
    'Total Pitches': pitches,
    'Total Present Days': present_days,
    'Total Investments': investments
})

# Extract data for Season 2
season_3_data = data.loc[3]

# Prepare data for pie chart
labels = [
    f'Present: {season_3_data["Total Present Days"]} ({season_3_data["Total Present Days"]/season_3_data["Total Pitches"]*100:.0f}%)',
    f'Absent: {season_3_data["Total Pitches"] - season_3_data["Total Present Days"]} ({(season_3_data["Total Pitches"] - season_3_data["Total Present Days"])/season_3_data["Total Pitches"]*100:.0f}%)'
]
sizes = [season_3_data['Total Present Days'], season_3_data['Total Pitches'] - season_3_data['Total Present Days']]
colors = ['orange', 'lightgrey']

# Plotting the pie chart
fig, ax = plt.subplots(figsize=(4, 4))
ax.pie(sizes, labels=labels, colors=colors, autopct='%1.0f%%', wedgeprops=dict(width=0.6), startangle=60)

# Add title
ax.set_title('Attendance Report (Season 3)')

# Display the pie chart
plt.show()

# %% [markdown]
# ## Overall Attendance Report (All Seasons)

# %%
# Filter out investments where the amount is greater than 0
df_invested = df[df['Ashneer Investment Amount'] > 0]

# Calculate the total number of pitches across all seasons
total_pitches = df['Season'].count()

# Calculate the total present days across all seasons
total_present_days = df['Ashneer Present'].sum()

# Calculate the total number of investments across all seasons (where investment amount > 0)
total_investments = df_invested.shape[0]

# Prepare data for pie chart
labels = [
    f'Present: {total_present_days} ({total_present_days/total_pitches*100:.0f}%)',
    f'Absent: {total_pitches - total_present_days} ({(total_pitches - total_present_days)/total_pitches*100:.0f}%)'
]
sizes = [total_present_days, total_pitches - total_present_days]
colors = ['orange', 'lightgrey']

# Plotting the pie chart
fig, ax = plt.subplots(figsize=(4, 4))
ax.pie(sizes, labels=labels, colors=colors, autopct='%1.0f%%', wedgeprops=dict(width=0.6))

# Add title
ax.set_title('Overall Attendance Report (All Seasons)')

# Display the pie chart
plt.show()

# %% [markdown]
# ## Distribution of Deals Based-on Attendance (Season 1)

# %%
# Filter out investments where the amount is greater than 0
df_invested = df[df['Ashneer Investment Amount'] > 0]

# Calculate the total number of pitches per season
pitches = df.groupby('Season').size()

# Calculate the total present days per season
present_days = df.groupby('Season')['Ashneer Present'].sum()

# Calculate the total number of investments per season (where investment amount > 0)
investments = df_invested.groupby('Season').size()

# Create a DataFrame with the required values
data = pd.DataFrame({
    'Total Pitches': pitches,
    'Total Present Days': present_days,
    'Total Investments': investments
})

# Filter data for Season 1
season_1_data = data.loc[1]  # Assuming Season 1 is labeled as 1

# Calculate the percentage of investments relative to present days
investment_percentage = (season_1_data['Total Investments'] / season_1_data['Total Present Days']) * 100
present_days_percentage = 100 - investment_percentage

# Prepare data for pie chart
labels = [
    f'Successful Deal\n({season_1_data["Total Investments"]})',
    f'Un-successful Deal\n({season_1_data["Total Present Days"] - season_1_data["Total Investments"]})'
]
sizes = [investment_percentage, present_days_percentage]
colors = ['#FAD02C', '#E9EAEC']
explode = (0.1, 0)  # Explode the first slice for emphasis

# Plotting the pie chart
fig, ax = plt.subplots(figsize=(4, 4))
ax.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.0f%%', startangle=90, shadow=True)

# Add title
ax.set_title('Deal Success Rate By Attendance (Season 1)')

# Display the plot
plt.show()

# %% [markdown]
# ## Distribution of Deals Based-on Attendance (Season 2)

# %%
# Filter out investments where the amount is greater than 0
df_invested = df[df['Ashneer Investment Amount'] > 0]

# Calculate the total number of pitches per season
pitches = df.groupby('Season').size()

# Calculate the total present days per season
present_days = df.groupby('Season')['Ashneer Present'].sum()

# Calculate the total number of investments per season (where investment amount > 0)
investments = df_invested.groupby('Season').size()

# Create a DataFrame with the required values
data = pd.DataFrame({
    'Total Pitches': pitches,
    'Total Present Days': present_days,
    'Total Investments': investments
})

# Filter data for Season 2
season_1_data = data.loc[2]  # Assuming Season 1 is labeled as 1

# Calculate the percentage of investments relative to present days
investment_percentage = (season_2_data['Total Investments'] / season_2_data['Total Present Days']) * 100
present_days_percentage = 100 - investment_percentage

# Prepare data for pie chart
labels = [
    f'Successful Deal\n({season_2_data["Total Investments"]})',
    f'Un-successful Deal\n({season_2_data["Total Present Days"] - season_2_data["Total Investments"]})'
]
sizes = [investment_percentage, present_days_percentage]
colors = ['#FAD02C', '#E9EAEC']
explode = (0.1, 0)  # Explode the first slice for emphasis

# Plotting the pie chart
fig, ax = plt.subplots(figsize=(4, 4))
ax.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.0f%%', startangle=90, shadow=True)

# Add title
ax.set_title('Deal Success Rate By Attendance (Season 2)')

# Display the plot
plt.show()

# %% [markdown]
# ## Distribution of Deals Based-on Attendance (Season 3)

# %%
# Filter out investments where the amount is greater than 0
df_invested = df[df['Ashneer Investment Amount'] > 0]

# Calculate the total number of pitches per season
pitches = df.groupby('Season').size()

# Calculate the total present days per season
present_days = df.groupby('Season')['Ashneer Present'].sum()

# Calculate the total number of investments per season (where investment amount > 0)
investments = df_invested.groupby('Season').size()

# Create a DataFrame with the required values
data = pd.DataFrame({
    'Total Pitches': pitches,
    'Total Present Days': present_days,
    'Total Investments': investments
})

# Filter data for Season 3
season_1_data = data.loc[3]  # Assuming Season 1 is labeled as 1

# Calculate the percentage of investments relative to present days
investment_percentage = (season_3_data['Total Investments'] / season_3_data['Total Present Days']) * 100
present_days_percentage = 100 - investment_percentage

# Prepare data for pie chart
labels = [
    f'Successful Deal\n({season_3_data["Total Investments"]})',
    f'Un-successful Deal\n({season_3_data["Total Present Days"] - season_3_data["Total Investments"]})'
]
sizes = [investment_percentage, present_days_percentage]
colors = ['#FAD02C', '#E9EAEC']
explode = (0.1, 0)  # Explode the first slice for emphasis

# Plotting the pie chart
fig, ax = plt.subplots(figsize=(4, 4))
ax.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.0f%%', startangle=90, shadow=True)

# Add title
ax.set_title('Deal Success Rate By Attendance (Season 3)')

# Display the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-40-5ca05d9741a4> in <cell line: 38>()
#      36 # Plotting the pie chart
#      37 fig, ax = plt.subplots(figsize=(4, 4))
# ---> 38 ax.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.0f%%', startangle=90, shadow=True)
#      39
#      40 # Add title
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1440     def inner(ax, *args, data=None, **kwargs):
#    1441         if data is None:
# -> 1442             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1443
#    1444         bound = new_sig.bind(ax, *args, **kwargs)
#
# ...

# %% [markdown]
# ## Deal Success Rate By Attendance (All Seasons) - Shark Ashneer Grover

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Filter out investments where the amount is greater than 0
df_invested = df[df['Ashneer Investment Amount'] > 0]

# Calculate the total number of pitches per season
pitches = df.groupby('Season').size()

# Calculate the total present days per season
present_days = df.groupby('Season')['Ashneer Present'].sum()

# Calculate the total number of investments per season (where investment amount > 0)
investments = df_invested.groupby('Season').size()

# Create a DataFrame with the required values
data = pd.DataFrame({
    'Total Pitches': pitches,
    'Total Present Days': present_days,
    'Total Investments': investments
})

# Calculate the percentage of investments relative to present days
total_investments = data['Total Investments'].sum()
total_present_days = data['Total Present Days'].sum()
investment_percentage = (total_investments / total_present_days) * 100
present_days_percentage = 100 - investment_percentage

# Prepare data for pie chart
labels = ['Successful Deal', 'Un-successful Deal']
sizes = [investment_percentage, present_days_percentage]
colors = ['#FAD02C', '#E9EAEC']
explode = (0.1, 0)  # Explode the first slice for emphasis

# Plotting the pie chart
fig, ax = plt.subplots(figsize=(4, 4))
ax.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.0f%%', startangle=90, shadow=True)

# Add title
ax.set_title('Deal Success Rate By Attendance (All Seasons) - Shark Ashneer Grover')

# Display the plot
plt.show()

# %% [markdown]
# ## Distribution of Deals Based-on Pitches (Season 1)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Filter out investments where the amount is greater than 0
df_invested = df[df['Ashneer Investment Amount'] > 0]

# Calculate the total number of pitches per season
pitches = df.groupby('Season').size()

# Calculate the total present days per season
present_days = df.groupby('Season')['Pitch'].sum()

# Calculate the total number of investments per season (where investment amount > 0)
investments = df_invested.groupby('Season').size()

# Create a DataFrame with the required values
data = pd.DataFrame({
    'Total Pitches': pitches,
    'Total Present Days': present_days,
    'Total Investments': investments
})

# Filter data for Season 1
season_1_data = data.loc[1]  # Assuming Season 1 is labeled as 1

# Calculate the percentage of investments relative to present days
investment_percentage = (season_1_data['Total Investments'] / season_1_data['Total Pitches']) * 100
present_days_percentage = 100 - investment_percentage

# Prepare data for pie chart
labels = ['Successful Deal', 'Un-successful Deal']
sizes = [investment_percentage, present_days_percentage]
colors = ['#FAD02C', '#E9EAEC']
explode = (0.1, 0)  # Explode the first slice for emphasis

# Define a function to display both percentage and actual values
def func(pct, allvals):
    absolute = int(round(pct/100.*np.sum(allvals)))
    return "{:.1f}%\n({:d})".format(pct, absolute)

# Plotting the pie chart
fig, ax = plt.subplots(figsize=(4, 4))
ax.pie(sizes, explode=explode, labels=labels, colors=colors, autopct=lambda pct: func(pct, [season_1_data['Total Investments'], season_1_data['Total Pitches'] - season_1_data['Total Investments']]), startangle=90, shadow=True, counterclock=False)

# Add title
ax.set_title('Deal Success Rate By Pitches (Season 1)')

# Display the plot
plt.show()

# %% [markdown]
# ## Distribution of Deals Based-on Pitches (Season 2)

# %%
# Filter out investments where the amount is greater than 0
df_invested = df[df['Ashneer Investment Amount'] > 0]

# Calculate the total number of pitches per season
pitches = df.groupby('Season').size()

# Calculate the total present days per season
present_days = df.groupby('Season')['Pitch'].sum()

# Calculate the total number of investments per season (where investment amount > 0)
investments = df_invested.groupby('Season').size()

# Create a DataFrame with the required values
data = pd.DataFrame({
    'Total Pitches': pitches,
    'Total Present Days': present_days,
    'Total Investments': investments
})

# Filter data for Season 2
season_3_data = data.loc[2]  # Assuming Season 1 is labeled as 1

# Calculate the percentage of investments relative to present days
investment_percentage = (season_2_data['Total Investments'] / season_2_data['Total Pitches']) * 100
present_days_percentage = 100 - investment_percentage

# Prepare data for pie chart
labels = ['Successful Deal', 'Un-successful Deal']
sizes = [investment_percentage, present_days_percentage]
colors = ['#FAD02C', '#E9EAEC']
explode = (0.1, 0)  # Explode the first slice for emphasis

# Define a function to display both percentage and actual values
def func(pct, allvals):
    absolute = int(round(pct/100.*np.sum(allvals)))
    return "{:.1f}%\n({:d})".format(pct, absolute)

# Plotting the pie chart
fig, ax = plt.subplots(figsize=(4, 4))
ax.pie(sizes, explode=explode, labels=labels, colors=colors, autopct=lambda pct: func(pct, [season_2_data['Total Investments'], season_2_data['Total Pitches'] - season_2_data['Total Investments']]), startangle=90, shadow=True, counterclock=False)

# Add title
ax.set_title('Deal Success Rate By Pitches (Season 2)')

# Display the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3790         try:
# -> 3791             return self._engine.get_loc(casted_key)
#    3792         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Total Investments'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-41-512eb01251e9> in <cell line: 24>()
#      22
# ...

# %% [markdown]
# ## Distribution of Deals Based-on Pitches (Season 3)

# %%
# Filter out investments where the amount is greater than 0
df_invested = df[df['Ashneer Investment Amount'] > 0]

# Calculate the total number of pitches per season
pitches = df.groupby('Season').size()

# Calculate the total present days per season
present_days = df.groupby('Season')['Pitch'].sum()

# Calculate the total number of investments per season (where investment amount > 0)
investments = df_invested.groupby('Season').size()

# Create a DataFrame with the required values
data = pd.DataFrame({
    'Total Pitches': pitches,
    'Total Present Days': present_days,
    'Total Investments': investments
})

# Filter data for Season 2
season_3_data = data.loc[3]  # Assuming Season 1 is labeled as 1

# Calculate the percentage of investments relative to present days
investment_percentage = (season_3_data['Total Investments'] / season_3_data['Total Pitches']) * 100
present_days_percentage = 100 - investment_percentage

# Prepare data for pie chart
labels = ['Successful Deal', 'Un-successful Deal']
sizes = [investment_percentage, present_days_percentage]
colors = ['#FAD02C', '#E9EAEC']
explode = (0.1, 0)  # Explode the first slice for emphasis

# Define a function to display both percentage and actual values
def func(pct, allvals):
    absolute = int(round(pct/100.*np.sum(allvals)))
    return "{:.1f}%\n({:d})".format(pct, absolute)

# Plotting the pie chart
fig, ax = plt.subplots(figsize=(4, 4))
ax.pie(sizes, explode=explode, labels=labels, colors=colors, autopct=lambda pct: func(pct, [season_3_data['Total Investments'], season_3_data['Total Pitches'] - season_3_data['Total Investments']]), startangle=90, shadow=True, counterclock=False)

# Add title
ax.set_title('Deal Success Rate By Pitches (Season 3)')

# Display the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-37-2f9e6757fe9d> in <cell line: 40>()
#      38 # Plotting the pie chart
#      39 fig, ax = plt.subplots(figsize=(4, 4))
# ---> 40 ax.pie(sizes, explode=explode, labels=labels, colors=colors, autopct=lambda pct: func(pct, [season_3_data['Total Investments'], season_3_data['Total Pitches'] - season_3_data['Total Investments']]), startangle=90, shadow=True, counterclock=False)
#      41
#      42 # Add title
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1440     def inner(ax, *args, data=None, **kwargs):
#    1441         if data is None:
# -> 1442             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1443
#    1444         bound = new_sig.bind(ax, *args, **kwargs)
#
# ...

# %% [markdown]
# ## Age Group Distribution (Season 1)

# %%
# Filter the data where Ashneer Investment Amount is greater than 0 and the Season is 1
Ashneer_investments = df[(df['Ashneer Investment Amount'] > 0) & (df['Season'] == 1)]

# Group by Presenters Average Age and count the investments
investment_counts = Ashneer_investments.groupby('Presenters Average Age').size()

# Plot the pie chart
plt.figure(figsize=(4, 4))
color = ['b','g','orange']
plt.pie(investment_counts, labels=investment_counts.index, autopct='%1.0f%%', textprops={'fontsize': 12}, shadow=True, colors=color)
plt.title('Age Group Distribution (Season 1)', color='r', fontsize=12, fontstyle='oblique')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Age Group Distribution (Season 2)

# %%
import plotly.graph_objects as go

# Filter the data where Ashneer Investment Amount is greater than 0 and the Season is 2
Ashneer_investments = df[(df['Ashneer Investment Amount'] > 0) & (df['Season'] == 2)]

# Group by Presenters Average Age and count the investments
investment_counts = Ashneer_investments.groupby('Presenters Average Age').size()

# Define an attractive red and green color scheme
color_scale = ['#ff4d4d', '#4dff4d', '#ff7f7f', '#7fff7f', '#d9534f']

# Create a pie chart using Plotly
fig = go.Figure(data=[go.Pie(
    labels=investment_counts.index,
    values=investment_counts,
    hoverinfo='label+percent+value',
    textinfo='percent',
    textfont=dict(size=16, color='white'),
    marker=dict(colors=color_scale, line=dict(color='#000000', width=2)),
    pull=[0.1, 0, 0, 0, 0]  # Highlight the first slice
)])

# Add title
fig.update_layout(
    title_text='Age Group Distribution (Season 2)',
    title_font=dict(size=30, color='red', family="Oblique"),
    title_x=0.5,  # Center the title
)

# Display the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## Age Group Distribution (Season 3)

# %%
import plotly.graph_objects as go

# Filter the data where Ashneer Investment Amount is greater than 0 and the Season is 2
Ashneer_investments = df[(df['Ashneer Investment Amount'] > 0) & (df['Season'] == 3)]

# Group by Presenters Average Age and count the investments
investment_counts = Ashneer_investments.groupby('Presenters Average Age').size()

# Define an attractive red and green color scheme
color_scale = ['#ff4d4d', '#4dff4d', '#ff7f7f', '#7fff7f', '#d9534f']

# Create a pie chart using Plotly
fig = go.Figure(data=[go.Pie(
    labels=investment_counts.index,
    values=investment_counts,
    hoverinfo='label+percent+value',
    textinfo='percent',
    textfont=dict(size=16, color='white'),
    marker=dict(colors=color_scale, line=dict(color='#000000', width=2)),
    pull=[0.1, 0, 0, 0, 0]  # Highlight the first slice
)])

# Add title
fig.update_layout(
    title_text='Age Group Distribution (Season 3)',
    title_font=dict(size=30, color='red', family="Oblique"),
    title_x=0.5,  # Center the title
)

# Display the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## Age Group-wise Investment Offered by Shark - Ashneer Grover

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Filter the data where Ashneer Investment Amount is greater than 0
Ashneer_investments = df[df['Ashneer Investment Amount'] > 0]

# Group by Season and Presenters Average Age, and count the investments
investment_counts = Ashneer_investments.groupby(['Season', 'Presenters Average Age']).size().unstack()

# Plot the stacked bar chart
ax = investment_counts.plot(kind='bar', stacked=True, figsize=(8, 4))

plt.title('Number of Pitches Offer Received by Shark - Ashneer Grover (By Age Group)', color='r', fontsize=12, fontstyle='oblique')
plt.xlabel('Season')
plt.ylabel('Number of Investments')
plt.legend(title='Presenters Average Age', loc='upper right')
plt.xticks(rotation=0)
plt.grid(linestyle='-', linewidth=0.3, axis='y')

# Adding actual values to each stack
for container in ax.containers:
    ax.bar_label(container, label_type='center', fontstyle='oblique', fontsize=10, color='w')

# Adding total values on top of each bar with the prefix 'Total'
totals = investment_counts.sum(axis=1)
for i, total in enumerate(totals):
    ax.text(i, total + 0.5, f'Total Pitches {int(total)}', ha='center', fontweight='bold', color='black')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Gender-wise Number of Presenters offered by Shark - Ashneer Grover

# %%
# Filter the data where Ashneer's investment amount is greater than 0
Ashneer_investment_data = df[df['Ashneer Investment Amount'] > 0]

# Group by Season and sum the number of male, female, and transgender presenters
grouped_data = Ashneer_investment_data.groupby('Season')[['Male Presenters', 'Female Presenters', 'Transgender Presenters']].sum()

# Plotting the stacked bar chart
ax = grouped_data.plot(kind='bar', stacked=True, figsize=(8, 4), color=['#1f77b4', '#ff7f0e', '#2ca02c'], edgecolor='black', linewidth=0.3)

plt.title('Number of Presenters offer Received by Shark - Ashneer Grover (By Gender)', color='r', fontsize=12, fontstyle='oblique')
plt.xlabel('Season')
plt.ylabel('Number of Presenters')
plt.legend(title='Presenter Type')
plt.xticks(rotation=0)
plt.grid(linestyle='-', linewidth=0.3, axis='y')

# Adding total values on top of each bar with the prefix 'Total Pitches'
totals = grouped_data.sum(axis=1)
for i, total in enumerate(totals):
    ax.text(i, total + 0.5, f'Total Presenters {int(total)}', ha='center', fontweight='bold', color='black')

# Adding actual values to each stack
for container in ax.containers:
    ax.bar_label(container, label_type='center', fontstyle='oblique', fontsize=12, color='w')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Gender and Age Analysis of Presenters Receiving Offers from Shark - Ashneer Grover (Season 1)

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator

# Filter the data where Ashneer's investment amount is greater than 0 and for Season 1
Ashneer_investment_data = df[(df['Ashneer Investment Amount'] > 0) & (df['Season'] == 1)]

# Group by Age Group and sum the number of male, female, and transgender presenters
grouped_data = Ashneer_investment_data.groupby('Presenters Average Age')[['Male Presenters', 'Female Presenters', 'Transgender Presenters']].sum()

# Plotting the tri-bar chart with increased bar width
fig, ax = plt.subplots(figsize=(8, 4))

# Define colors and styles
colors = ['#1f77b4', '#ff7f0e', '#2ca02c']
labels = ['Male Presenters', 'Female Presenters', 'Transgender Presenters']

# Create bars
bar_width = 0.8
grouped_data.plot(kind='bar', ax=ax, color=colors, width=bar_width, edgecolor='black')

# Customizing the appearance
plt.title('Number of presenters got offered for Season 1 (By Age Group & Gender)', color='#D62728', fontsize=12, fontweight='bold', fontstyle='italic')
plt.xlabel('Age Group (Presenters Avg Age)')
plt.ylabel('Number of Presenters')
plt.xticks(rotation=0)
plt.yticks()

# Set Y-axis ticks to integer values
ax.yaxis.set_major_locator(MaxNLocator(integer=True))

plt.legend(title='Gender')
plt.grid(axis='y', linestyle='--', linewidth=0.7, alpha=0.7)

# Adding actual values on top of each bar
for container in ax.containers:
    ax.bar_label(container, label_type='edge', fontsize=10, color='black', fontweight='bold')

# Improve spacing and layout
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ## Gender and Age Analysis of Presenters Receiving Offers from Shark - Ashneer Grover (Season 2)

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator

# Filter the data where Ashneer's investment amount is greater than 0 and for Season 1
Ashneer_investment_data = df[(df['Ashneer Investment Amount'] > 0) & (df['Season'] == 2)]

# Group by Age Group and sum the number of male, female, and transgender presenters
grouped_data = Ashneer_investment_data.groupby('Presenters Average Age')[['Male Presenters', 'Female Presenters', 'Transgender Presenters']].sum()

# Plotting the tri-bar chart with increased bar width
fig, ax = plt.subplots(figsize=(8, 4))

# Define colors and styles
colors = ['#1f77b4', '#ff7f0e', '#2ca02c']
labels = ['Male Presenters', 'Female Presenters', 'Transgender Presenters']

# Create bars
bar_width = 0.8
grouped_data.plot(kind='bar', ax=ax, color=colors, width=bar_width, edgecolor='black')

# Customizing the appearance
plt.title('Number of presenters got offered for Season 2 (By Age Group & Gender)', color='#D62728', fontsize=12, fontweight='bold', fontstyle='italic')
plt.xlabel('Age Group (Presenters Avg Age)')
plt.ylabel('Number of Presenters')
plt.xticks(rotation=0)
plt.yticks()

# Set Y-axis ticks to integer values
ax.yaxis.set_major_locator(MaxNLocator(integer=True))

plt.legend(title='Gender')
plt.grid(axis='y', linestyle='--', linewidth=0.7, alpha=0.7)

# Adding actual values on top of each bar
for container in ax.containers:
    ax.bar_label(container, label_type='edge', fontsize=10, color='black', fontweight='bold')

# Improve spacing and layout
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-30-8d6f0886cc9b> in <cell line: 19>()
#      17 # Create bars
#      18 bar_width = 0.8
# ---> 19 grouped_data.plot(kind='bar', ax=ax, color=colors, width=bar_width, edgecolor='black')
#      20
#      21 # Customizing the appearance
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#    1029                     data.columns = label_name
#    1030
# -> 1031         return plot_backend.plot(data, kind=kind, **kwargs)
#    1032
#    1033     __call__.__doc__ = __doc__
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71     plot_obj.generate()
#      72     plot_obj.draw()
# ...

# %% [markdown]
# ## Gender and Age Analysis of Presenters Receiving Offers from Shark - Ashneer Grover (Season 3)

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator

# Filter the data where Ashneer's investment amount is greater than 0 and for Season 1
Ashneer_investment_data = df[(df['Ashneer Investment Amount'] > 0) & (df['Season'] == 3)]

# Group by Age Group and sum the number of male, female, and transgender presenters
grouped_data = Ashneer_investment_data.groupby('Presenters Average Age')[['Male Presenters', 'Female Presenters', 'Transgender Presenters']].sum()

# Plotting the tri-bar chart with increased bar width
fig, ax = plt.subplots(figsize=(8, 4))

# Define colors and styles
colors = ['#1f77b4', '#ff7f0e', '#2ca02c']
labels = ['Male Presenters', 'Female Presenters', 'Transgender Presenters']

# Create bars
bar_width = 0.8
grouped_data.plot(kind='bar', ax=ax, color=colors, width=bar_width, edgecolor='black')

# Customizing the appearance
plt.title('Number of presenters got offered for Season 3 (By Age Group & Gender)', color='#D62728', fontsize=12, fontweight='bold', fontstyle='italic')
plt.xlabel('Age Group (Presenters Avg Age)')
plt.ylabel('Number of Presenters')
plt.xticks(rotation=0)
plt.yticks()

# Set Y-axis ticks to integer values
ax.yaxis.set_major_locator(MaxNLocator(integer=True))

plt.legend(title='Gender')
plt.grid(axis='y', linestyle='--', linewidth=0.7, alpha=0.7)

# Adding actual values on top of each bar
for container in ax.containers:
    ax.bar_label(container, label_type='edge', fontsize=10, color='black', fontweight='bold')

# Improve spacing and layout
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-53-81768a337026> in <cell line: 19>()
#      17 # Create bars
#      18 bar_width = 0.8
# ---> 19 grouped_data.plot(kind='bar', ax=ax, color=colors, width=bar_width, edgecolor='black')
#      20
#      21 # Customizing the appearance
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#    1029                     data.columns = label_name
#    1030
# -> 1031         return plot_backend.plot(data, kind=kind, **kwargs)
#    1032
#    1033     __call__.__doc__ = __doc__
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71     plot_obj.generate()
#      72     plot_obj.draw()
# ...

# %% [markdown]
# ## Gender and Age Analysis of Presenters Receiving Offers from Shark - Ashneer Grover (Season All)

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator

# Filter the data where Ashneer's investment amount is greater than 0 and for Season 1
Ashneer_investment_data = df[(df['Ashneer Investment Amount'] > 0) ]

# Group by Age Group and sum the number of male, female, and transgender presenters
grouped_data = Ashneer_investment_data.groupby('Presenters Average Age')[['Male Presenters', 'Female Presenters', 'Transgender Presenters']].sum()

# Plotting the tri-bar chart with increased bar width
fig, ax = plt.subplots(figsize=(8, 4))

# Define colors and styles
colors = ['#1f77b4', '#ff7f0e', '#2ca02c']
labels = ['Male Presenters', 'Female Presenters', 'Transgender Presenters']

# Create bars
bar_width = 0.8
grouped_data.plot(kind='bar', ax=ax, color=colors, width=bar_width, edgecolor='black')

# Customizing the appearance
plt.title('Number of presenters got offered for All Season (By Age Group & Gender)', color='#D62728', fontsize=12, fontweight='bold', fontstyle='italic')
plt.xlabel('Age Group (Presenters Avg Age)')
plt.ylabel('Number of Presenters')
plt.xticks(rotation=0)
plt.yticks()

# Set Y-axis ticks to integer values
ax.yaxis.set_major_locator(MaxNLocator(integer=True))

plt.legend(title='Gender')
plt.grid(axis='y', linestyle='--', linewidth=0.7, alpha=0.7)

# Adding actual values on top of each bar
for container in ax.containers:
    ax.bar_label(container, label_type='edge', fontsize=10, color='black', fontweight='bold')

# Improve spacing and layout
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ## Deals done by shark - Ashneer Grover

# %%
Ashneer_invested = df[df['Ashneer Investment Amount'] > 0]

# Group by season and count the number of pitches
pitches_per_season = Ashneer_invested.groupby('Season')['Pitch'].count()

# Plotting the bar chart
plt.figure(figsize=(8, 4))
bars = pitches_per_season.plot(kind='bar', color='skyblue')
plt.title('Successful Deals Across Seasons By Shark - Ashneer Grover', color='r', fontsize=12, fontstyle='oblique')
plt.xlabel('Season')
plt.ylabel('Successful Deals')
plt.xticks(rotation=0)
plt.grid(linestyle='-', linewidth=0.5, axis='y')

# Adding actual values on top of each bar
for bar in bars.patches:
  height = bar.get_height()
  plt.text(bar.get_x() + bar.get_width() / 2, height + 0.2,  # Position of the text
             f'{int(height)} Deals',  # Value to be displayed
             ha='center', va='bottom', fontsize=11.5)

plt.show()

# %% [markdown]
# ## Industry-wise Investment by Shark - Ashneer Grover (Season 1)

# %%
# Filter the data for Season 1
season_1_data = df[df['Season'] == 1]

# Filter for investments by Ashneer greater than 0
Ashneer_investments = season_1_data[season_1_data['Ashneer Investment Amount'] > 0]

# Group by Industry and count the number of investments
industry_investment_count = Ashneer_investments.groupby('Industry')['Ashneer Investment Amount'].count().reset_index()

# Sort by the count of investments
industry_investment_count = industry_investment_count.sort_values(by='Ashneer Investment Amount', ascending=False)

# Plotting
fig = go.Figure()

# Add line trace with markers
fig.add_trace(go.Scatter(
    x=industry_investment_count['Industry'],  # x-values (Industry names)
    y=industry_investment_count['Ashneer Investment Amount'],  # y-values (Count of investments)
    mode='lines+markers',  # Show lines and markers
    line=dict(color='royalblue', width=2),  # Line color and width
    marker=dict(size=8, color='royalblue'),  # Marker size and color
    text=industry_investment_count['Ashneer Investment Amount'],  # Add text labels
    textposition='top center',  # Position text labels
    name='Investments'
))

# Update layout with grid lines
fig.update_layout(
    title='Industry-wise Investment by Shark - Ashneer Grover (Season 1)',
    title_font=dict(size=20, color='red', family='Arial, sans-serif'),
    xaxis_title='Industry',
    yaxis_title='Number of Offered Investments',
    xaxis=dict(
        title_font=dict(size=20, family='Arial, sans-serif'),
        tickfont=dict(size=20, family='Arial, sans-serif'),
        tickangle=-45,  # Rotate x-axis labels for better readability
        showgrid=True,  # Show grid lines
        gridcolor='lightgray',  # Grid line color
        gridwidth=0.5  # Grid line width
    ),
    yaxis=dict(
        title_font=dict(size=20, family='Arial, sans-serif'),
        tickfont=dict(size=20, family='Arial, sans-serif'),
        tickmode='linear',
        showgrid=True,  # Show grid lines
        gridcolor='lightgray',  # Grid line color
        gridwidth=0.5  # Grid line width
    ),
    plot_bgcolor='white',
    paper_bgcolor='rgba(240,240,240,0.5)',
    margin=dict(l=80, r=20, t=50, b=50),
    font=dict(family='Arial, sans-serif', size=12, color='black')
)

# Show plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## Industry-wise Investment by Shark - Ashneer Grover (Season 2)

# %%
# Filter the data for Season 2
season_2_data = df[df['Season'] == 2]

# Filter for investments by Ashneer greater than 0
Ashneer_investments = season_2_data[season_2_data['Ashneer Investment Amount'] > 0]

# Group by Industry and count the number of investments
industry_investment_count = Ashneer_investments.groupby('Industry')['Ashneer Investment Amount'].count().reset_index()

# Sort by the count of investments
industry_investment_count = industry_investment_count.sort_values(by='Ashneer Investment Amount', ascending=False)

# Plotting
fig = go.Figure()

# Add line trace with markers
fig.add_trace(go.Scatter(
    x=industry_investment_count['Industry'],  # x-values (Industry names)
    y=industry_investment_count['Ashneer Investment Amount'],  # y-values (Count of investments)
    mode='lines+markers',  # Show lines and markers
    line=dict(color='royalblue', width=2),  # Line color and width
    marker=dict(size=8, color='royalblue'),  # Marker size and color
    text=industry_investment_count['Ashneer Investment Amount'],  # Add text labels
    textposition='top center',  # Position text labels
    name='Investments'
))

# Update layout with grid lines
fig.update_layout(
    title='Industry-wise Investment by Shark - Ashneer Grover (Season 2)',
    title_font=dict(size=20, color='red', family='Arial, sans-serif'),
    xaxis_title='Industry',
    yaxis_title='Number of Offered Investments',
    xaxis=dict(
        title_font=dict(size=20, family='Arial, sans-serif'),
        tickfont=dict(size=20, family='Arial, sans-serif'),
        tickangle=-45,  # Rotate x-axis labels for better readability
        showgrid=True,  # Show grid lines
        gridcolor='lightgray',  # Grid line color
        gridwidth=0.5  # Grid line width
    ),
    yaxis=dict(
        title_font=dict(size=20, family='Arial, sans-serif'),
        tickfont=dict(size=20, family='Arial, sans-serif'),
        tickmode='linear',
        showgrid=True,  # Show grid lines
        gridcolor='lightgray',  # Grid line color
        gridwidth=0.5  # Grid line width
    ),
    plot_bgcolor='white',
    paper_bgcolor='rgba(240,240,240,0.5)',
    margin=dict(l=80, r=20, t=50, b=50),
    font=dict(family='Arial, sans-serif', size=12, color='black')
)

# Show plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## Industry-wise Investment by Shark - Ashneer Grover (Season 3)

# %%
# Filter the data for Season 3
season_3_data = df[df['Season'] == 3]

# Filter for investments by Ashneer greater than 0
Ashneer_investments = season_3_data[season_3_data['Ashneer Investment Amount'] > 0]

# Group by Industry and count the number of investments
industry_investment_count = Ashneer_investments.groupby('Industry')['Ashneer Investment Amount'].count().reset_index()

# Sort by the count of investments
industry_investment_count = industry_investment_count.sort_values(by='Ashneer Investment Amount', ascending=False)

# Plotting
fig = go.Figure()

# Add line trace with markers
fig.add_trace(go.Scatter(
    x=industry_investment_count['Industry'],  # x-values (Industry names)
    y=industry_investment_count['Ashneer Investment Amount'],  # y-values (Count of investments)
    mode='lines+markers',  # Show lines and markers
    line=dict(color='royalblue', width=2),  # Line color and width
    marker=dict(size=8, color='royalblue'),  # Marker size and color
    text=industry_investment_count['Ashneer Investment Amount'],  # Add text labels
    textposition='top center',  # Position text labels
    name='Investments'
))

# Update layout with grid lines
fig.update_layout(
    title='Industry-wise Investment by Shark - Ashneer Grover (Season 3)',
    title_font=dict(size=20, color='red', family='Arial, sans-serif'),
    xaxis_title='Industry',
    yaxis_title='Number of Offered Investments',
    xaxis=dict(
        title_font=dict(size=20, family='Arial, sans-serif'),
        tickfont=dict(size=20, family='Arial, sans-serif'),
        tickangle=-45,  # Rotate x-axis labels for better readability
        showgrid=True,  # Show grid lines
        gridcolor='lightgray',  # Grid line color
        gridwidth=0.5  # Grid line width
    ),
    yaxis=dict(
        title_font=dict(size=20, family='Arial, sans-serif'),
        tickfont=dict(size=20, family='Arial, sans-serif'),
        tickmode='linear',
        showgrid=True,  # Show grid lines
        gridcolor='lightgray',  # Grid line color
        gridwidth=0.5  # Grid line width
    ),
    plot_bgcolor='white',
    paper_bgcolor='rgba(240,240,240,0.5)',
    margin=dict(l=80, r=20, t=50, b=50),
    font=dict(family='Arial, sans-serif', size=12, color='black')
)

# Show plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## Industry-wise Investment by Shark - Ashneer Grover (Season All)

# %%
# Filter for investments by Ashneer greater than 0
Ashneer_investments = df[df['Ashneer Investment Amount'] > 0]

# Group by Industry and count the number of investments
industry_investment_count = Ashneer_investments.groupby('Industry')['Ashneer Investment Amount'].count().reset_index()

# Sort by the count of investments
industry_investment_count = industry_investment_count.sort_values(by='Ashneer Investment Amount', ascending=False)

# Plotting
fig = go.Figure()

# Add line trace with markers
fig.add_trace(go.Scatter(
    x=industry_investment_count['Industry'],  # x-values (Industry names)
    y=industry_investment_count['Ashneer Investment Amount'],  # y-values (Count of investments)
    mode='lines+markers',  # Show lines and markers
    line=dict(color='green', width=2),  # Line color and width
    marker=dict(size=8, color='green'),  # Marker size and color
    text=industry_investment_count['Ashneer Investment Amount'],  # Add text labels
    textposition='top center',  # Position text labels
    name='Investments'
))

# Update layout with grid lines
fig.update_layout(
    title='Industry-wise Investment by Shark - Ashneer Grover (All Seasons)',
    title_font=dict(size=20, color='red', family='Arial, sans-serif'),
    xaxis_title='Industry',
    yaxis_title='Number of Offered Investments',
    xaxis=dict(
        title_font=dict(size=20, family='Arial, sans-serif'),
        tickfont=dict(size=20, family='Arial, sans-serif'),
        tickangle=-45,  # Rotate x-axis labels for better readability
        showgrid=True,  # Show grid lines
        gridcolor='lightgray',  # Grid line color
        gridwidth=0.5  # Grid line width
    ),
    yaxis=dict(
        title_font=dict(size=20, family='Arial, sans-serif'),
        tickfont=dict(size=20, family='Arial, sans-serif'),
        tickmode='linear',
        dtick=2,  # Set y-axis step to 2
        showgrid=True,  # Show grid lines
        gridcolor='lightgray',  # Grid line color
        gridwidth=0.5  # Grid line width
    ),
    plot_bgcolor='white',
    paper_bgcolor='rgba(240,240,240,0.5)',
    margin=dict(l=80, r=20, t=50, b=50),
    font=dict(family='Arial, sans-serif', size=12, color='black')
)

# Show plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## Ashneer Grover's Investment Amount by Industry (Season 1)

# %%
# Filter the data for Season 1
season_1_data = df[df['Season'] == 1]

# Filter for investments by Ashneer greater than 0
Ashneer_investments = season_1_data[season_1_data['Ashneer Investment Amount'] > 0]

# Create a pivot table for investment amounts by industry
industry_investments = Ashneer_investments.pivot_table(index='Industry',
    values='Ashneer Investment Amount',
    aggfunc='sum'
)

# Sort the industries by the highest investment amount
industry_investments = industry_investments.sort_values(by='Ashneer Investment Amount', ascending=False)

# Plotting the heatmap
plt.figure(figsize=(8, 6))  # Increased figure size for better readability
sns.heatmap(industry_investments, annot=True, fmt='.2f', cmap='RdYlGn', cbar_kws={'shrink': 0.8}, linewidths=1, linecolor='black')

# Customizing the title and labels
plt.title("Ashneer Grover's Investment Amount by Industry (Season 1)", fontsize=18, color='darkblue', fontweight='bold', pad=20)
plt.xlabel('Industry', fontsize=14, color='darkgreen', fontweight='bold')
plt.ylabel('Investment Amount (in Lakh)', fontsize=14, color='darkgreen', fontweight='bold')

# Rotating the x-axis labels for better readability
plt.xticks(ha='center', fontsize=14, color='darkred')
plt.yticks(fontsize=12, color='darkred')
# Displaying the plot
plt.show()

# %% [markdown]
# ## Ashneer Grover's Investment Amount by Industry (Season 2)

# %%
# Filter the data for Season 2
season_2_data = df[df['Season'] == 2]

# Filter for investments by Ashneer greater than 0
Ashneer_investments = season_2_data[season_2_data['Ashneer Investment Amount'] > 0]

# Create a pivot table for investment amounts by industry
industry_investments = Ashneer_investments.pivot_table(index='Industry',
    values='Ashneer Investment Amount',
    aggfunc='sum'
)

# Sort the industries by the highest investment amount
industry_investments = industry_investments.sort_values(by='Ashneer Investment Amount', ascending=False)

# Plotting the heatmap
plt.figure(figsize=(8, 6))  # Increased figure size for better readability
sns.heatmap(industry_investments, annot=True, fmt='.2f', cmap='RdYlGn', cbar_kws={'shrink': 0.8}, linewidths=1, linecolor='black')

# Customizing the title and labels
plt.title("Ashneer Grover's Investment Amount by Industry (Season 2)", fontsize=18, color='darkblue', fontweight='bold', pad=20)
plt.xlabel('Industry', fontsize=14, color='darkgreen', fontweight='bold')
plt.ylabel('Investment Amount (in Lakh)', fontsize=14, color='darkgreen', fontweight='bold')

# Rotating the x-axis labels for better readability
plt.xticks(ha='center', fontsize=14, color='darkred')
plt.yticks(fontsize=12, color='darkred')
# Displaying the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-52-53e4d43c26f3> in <cell line: 14>()
#      12
#      13 # Sort the industries by the highest investment amount
# ---> 14 industry_investments = industry_investments.sort_values(by='Ashneer Investment Amount', ascending=False)
#      15
#      16 # Plotting the heatmap
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6942             # len(by) == 1
#    6943
# -> 6944             k = self._get_label_or_level_values(by[0], axis=axis)
#    6945
#    6946             # need to rewrap column in Series to apply key function
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1842             values = self.axes[axis].get_level_values(key)._values
# ...

# %% [markdown]
# ## Ashneer Grover's Investment Amount by Industry (Season 3)

# %%
# Filter the data for Season 3
season_3_data = df[df['Season'] == 3]

# Filter for investments by Ashneer greater than 0
Ashneer_investments = season_3_data[season_3_data['Ashneer Investment Amount'] > 0]

# Create a pivot table for investment amounts by industry
industry_investments = Ashneer_investments.pivot_table(index='Industry',
    values='Ashneer Investment Amount',
    aggfunc='sum'
)

# Sort the industries by the highest investment amount
industry_investments = industry_investments.sort_values(by='Ashneer Investment Amount', ascending=False)
# Plotting the heatmap
plt.figure(figsize=(8, 6))  # Increased figure size for better readability
sns.heatmap(industry_investments, annot=True, fmt='.2f', cmap='RdYlGn', cbar_kws={'shrink': 0.8}, linewidths=1, linecolor='black')

# Customizing the title and labels
plt.title("Ashneer Grover's Investment Amount by Industry (Season 3)", fontsize=18, color='darkblue', fontweight='bold', pad=20)
plt.xlabel('Industry', fontsize=14, color='darkgreen', fontweight='bold')
plt.ylabel('Investment Amount (in Lakh)', fontsize=14, color='darkgreen', fontweight='bold')

# Rotating the x-axis labels for better readability
plt.xticks(ha='center', fontsize=14, color='darkred')
plt.yticks(fontsize=12, color='darkred')

# Displaying the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-50-1115024f097c> in <cell line: 14>()
#      12
#      13 # Sort the industries by the highest investment amount
# ---> 14 industry_investments = industry_investments.sort_values(by='Ashneer Investment Amount', ascending=False)
#      15 # Plotting the heatmap
#      16 plt.figure(figsize=(8, 6))  # Increased figure size for better readability
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6942             # len(by) == 1
#    6943
# -> 6944             k = self._get_label_or_level_values(by[0], axis=axis)
#    6945
#    6946             # need to rewrap column in Series to apply key function
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
# ...

# %% [markdown]
# ## Ashneer Grover's Investment Amount by Industry (Season All)

# %%
# Filter for investments by Ashneer greater than 0
Ashneer_investments = df[df['Ashneer Investment Amount'] > 0]

# Create a pivot table for investment amounts by industry
industry_investments = Ashneer_investments.pivot_table(
    index='Industry',
    values='Ashneer Investment Amount',
    aggfunc='sum'
)

# Sort the industries by the highest investment amount
industry_investments = industry_investments.sort_values(by='Ashneer Investment Amount', ascending=False)

# Plotting the heatmap
plt.figure(figsize=(8, 6))  # Increased figure size for better readability
sns.heatmap(industry_investments, annot=True, fmt='.2f', cmap='RdYlGn', cbar_kws={'shrink': 0.8}, linewidths=1, linecolor='black')

# Customizing the title and labels
plt.title("Ashneer Grover's Investment Amount by Industry (All Seasons)", fontsize=18, color='darkblue', fontweight='bold', pad=20)
plt.xlabel('Industry', fontsize=14, color='darkgreen', fontweight='bold')
plt.ylabel('Investment Amount (in Lakh)', fontsize=14, color='darkgreen', fontweight='bold')

# Rotating the x-axis labels for better readability
plt.xticks(ha='center', fontsize=14, color='darkred')
plt.yticks(fontsize=12, color='darkred')

# Displaying the plot
plt.show()

# %% [markdown]
# ## Ashneer Grover's Investment Amount by Pitches (Season 1)

# %%
# Filter the data for Season 1
season_1_data = df[df['Season'] == 1]

# Filter for investments by Ashneer greater than 0
Ashneer_investments = season_1_data[season_1_data['Ashneer Investment Amount'] > 0]

# Create a pivot table for investment amounts by industry
industry_investments = Ashneer_investments.pivot_table(index='Start-Ups Brand',
    values='Ashneer Investment Amount',
    aggfunc='sum'
)
# Sort the industries by the highest investment amount
industry_investments = industry_investments.sort_values(by='Ashneer Investment Amount', ascending=False)

# Plotting the heatmap
plt.figure(figsize=(8, 12))  # Increased figure size for better readability
sns.heatmap(industry_investments, annot=True, fmt='.2f', cmap='Blues', cbar_kws={'shrink': 0.8}, linewidths=1, linecolor='black')

# Customizing the title and labels
plt.title("Ashneer Grover's Investment Amount by Pitches (Season 1)", fontsize=18, color='darkblue', fontweight='bold', pad=20)
plt.xlabel('Startups (Pitches)', fontsize=14, color='darkblue', fontweight='bold')
plt.ylabel('Investment Amount (in Lakh)', fontsize=14, color='darkblue', fontweight='bold')

# Rotating the x-axis labels for better readability
plt.xticks(ha='center', fontsize=14, color='darkblue')
plt.yticks(fontsize=12, color='darkblue')

# Displaying the plot
plt.show()

# %% [markdown]
# ## Ashneer Grover's Investment Amount by Pitches (Season 2)

# %%
# Filter the data for Season 2
season_2_data = df[df['Season'] == 2]

# Filter for investments by Ashneer greater than 0
Ashneer_investments = season_2_data[season_2_data['Ashneer Investment Amount'] > 0]

# Create a pivot table for investment amounts by industry
industry_investments = Ashneer_investments.pivot_table(index='Start-Ups Brand',
    values='Ashneer Investment Amount',
    aggfunc='sum'
)
# Sort the industries by the highest investment amount
industry_investments = industry_investments.sort_values(by='Ashneer Investment Amount', ascending=False)

# Plotting the heatmap
plt.figure(figsize=(8, 12))  # Increased figure size for better readability
sns.heatmap(industry_investments, annot=True, fmt='.2f', cmap='Blues', cbar_kws={'shrink': 0.8}, linewidths=1, linecolor='black')

# Customizing the title and labels
plt.title("Ashneer Grover's Investment Amount by Pitches (Season 2)", fontsize=18, color='darkblue', fontweight='bold', pad=20)
plt.xlabel('Startups (Pitches)', fontsize=14, color='darkblue', fontweight='bold')
plt.ylabel('Investment Amount (in Lakh)', fontsize=14, color='darkblue', fontweight='bold')

# Rotating the x-axis labels for better readability
plt.xticks(ha='center', fontsize=14, color='darkblue')
plt.yticks(fontsize=12, color='darkblue')

# Displaying the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-49-32a34c3c4316> in <cell line: 13>()
#      11 )
#      12 # Sort the industries by the highest investment amount
# ---> 13 industry_investments = industry_investments.sort_values(by='Ashneer Investment Amount', ascending=False)
#      14
#      15 # Plotting the heatmap
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6942             # len(by) == 1
#    6943
# -> 6944             k = self._get_label_or_level_values(by[0], axis=axis)
#    6945
#    6946             # need to rewrap column in Series to apply key function
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
# ...

# %% [markdown]
# ## Ashneer Grover's Investment Amount by Pitches (Season 3)

# %%
# Filter the data for Season 3
season_3_data = df[df['Season'] == 3]

# Filter for investments by Ashneer greater than 0
Ashneer_investments = season_3_data[season_3_data['Ashneer Investment Amount'] > 0]

# Create a pivot table for investment amounts by industry
industry_investments = Ashneer_investments.pivot_table(index='Start-Ups Brand',
    values='Ashneer Investment Amount',
    aggfunc='sum'
)
# Sort the industries by the highest investment amount
industry_investments = industry_investments.sort_values(by='Ashneer Investment Amount', ascending=False)

# Plotting the heatmap
plt.figure(figsize=(8, 12))  # Increased figure size for better readability
sns.heatmap(industry_investments, annot=True, fmt='.2f', cmap='Blues', cbar_kws={'shrink': 0.8}, linewidths=1, linecolor='black')

# Customizing the title and labels
plt.title("Ashneer Grover's Investment Amount by Pitches (Season 3)", fontsize=18, color='darkblue', fontweight='bold', pad=20)
plt.xlabel('Startups (Pitches)', fontsize=14, color='darkblue', fontweight='bold')
plt.ylabel('Investment Amount (in Lakh)', fontsize=14, color='darkblue', fontweight='bold')

# Rotating the x-axis labels for better readability
plt.xticks(ha='center', fontsize=14, color='darkblue')
plt.yticks(fontsize=12, color='darkblue')

# Displaying the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-48-7459e9cb84a1> in <cell line: 13>()
#      11 )
#      12 # Sort the industries by the highest investment amount
# ---> 13 industry_investments = industry_investments.sort_values(by='Ashneer Investment Amount', ascending=False)
#      14
#      15 # Plotting the heatmap
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6942             # len(by) == 1
#    6943
# -> 6944             k = self._get_label_or_level_values(by[0], axis=axis)
#    6945
#    6946             # need to rewrap column in Series to apply key function
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
# ...

# %% [markdown]
# ## Ashneer Grover's Investment Amount by Pitches (Season All)

# %%
# Filter for investments by Ashneer greater than 0
Ashneer_investments = df[df['Ashneer Investment Amount'] > 0]

# Create a pivot table for investment amounts by industry
industry_investments = Ashneer_investments.pivot_table(index='Start-Ups Brand',
    values='Ashneer Investment Amount',
    aggfunc='sum'
)

# Sort the industries by the highest investment amount
industry_investments = industry_investments.sort_values(by='Ashneer Investment Amount', ascending=False)

# Plotting the heatmap
plt.figure(figsize=(16, 30))  # Increased figure size for better readability
sns.heatmap(industry_investments, annot=True, fmt='.2f', cmap='Blues', cbar_kws={'shrink': 0.8}, linewidths=0.5, linecolor='black')

# Customizing the title and labels
plt.title("Ashneer Grover's Investment Amount by Pitches (Season All)", fontsize=18, color='darkblue', fontweight='bold', pad=20)
plt.xlabel('Startups (Pitches)', fontsize=14, color='darkblue', fontweight='bold')
plt.ylabel('Investment Amount (in Lakh)', fontsize=14, color='darkblue', fontweight='bold')

# Rotating the x-axis labels for better readability
plt.xticks(ha='center', fontsize=14, color='darkblue')
plt.yticks(fontsize=12, color='darkblue')

# Displaying the plot
plt.show()

# %% [markdown]
# ## Gender Distribution (Season 1)

# %%
# Filter data for Season 1 and Ashneer's investments greater than 0
season_1_data = df[df['Season'] == 1]
Ashneer_investments = season_1_data[season_1_data['Ashneer Investment Amount'] > 0]

# Sum the number of presenters by gender for these filtered investments
presenters_data = Ashneer_investments[['Male Presenters', 'Female Presenters', 'Transgender Presenters']].sum()

# Plotting the pie chart
plt.figure(figsize=(6, 6))  # Increased figure size for better visibility
wedges, _, autotexts = plt.pie(
    presenters_data,
    colors=['#ff6f61', '#88b04b', '#b565a7'],  # Customized color scheme
    autopct='%1.2f%%',
    pctdistance=0.75,  # Pulls the percentage labels closer to the center
    shadow=True,  # Adds a shadow for a 3D effect
    wedgeprops={'edgecolor': 'black', 'linewidth': 1, 'antialiased': True}  # Enhances the wedge borders
)

# Increase font size for the percentage values
for autotext in autotexts:
    autotext.set_fontsize(14)  # Set font size to 14

# Adding a center circle to create a donut chart look
centre_circle = plt.Circle((0, 0), 0.50, fc='white')
plt.gca().add_artist(centre_circle)

# Adding a legend within the white circle area
plt.legend(wedges, ['Male', 'Female', 'Transgender'], title="Gender", loc="center", fontsize=12)

# Customizing the title
plt.title('Gender Distribution (Season 1)',
          fontsize=16, color='red', fontweight='bold', loc='center')

# Adjusting the layout for better spacing
plt.tight_layout()

# Displaying the plot
plt.show()

# %% [markdown]
# ## Gender Distribution (Season 2)

# %%
# Filter data for Season 2 and Ashneer's investments greater than 0
season_2_data = df[df['Season'] == 2]
Ashneer_investments = season_2_data[season_2_data['Ashneer Investment Amount'] > 0]

# Sum the number of presenters by gender for these filtered investments
presenters_data = Ashneer_investments[['Male Presenters', 'Female Presenters', 'Transgender Presenters']].sum()

# Plotting the pie chart
plt.figure(figsize=(6, 6))  # Increased figure size for better visibility
wedges, _, autotexts = plt.pie(
    presenters_data,
    colors=['#e67e22', '#2ecc71', '#f1c40f'],  # Customized color scheme
    autopct='%1.2f%%',
    pctdistance=0.75,  # Pulls the percentage labels closer to the center
    shadow=True,  # Adds a shadow for a 3D effect
    wedgeprops={'edgecolor': 'black', 'linewidth': 1, 'antialiased': True}  # Enhances the wedge borders
)

# Increase font size for the percentage values
for autotext in autotexts:
    autotext.set_fontsize(14)  # Set font size to 14

# Adding a center circle to create a donut chart look
centre_circle = plt.Circle((0, 0), 0.50, fc='white')
plt.gca().add_artist(centre_circle)

# Adding a legend within the white circle area
plt.legend(wedges, ['Male', 'Female', 'Transgender'], title="Gender", loc="center", fontsize=12)

# Customizing the title
plt.title('Gender Distribution (Season 2)',
          fontsize=16, color='red', fontweight='bold', loc='center')

# Adjusting the layout for better spacing
plt.tight_layout()

# Displaying the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-45-f3675356546b> in <cell line: 10>()
#       8 # Plotting the pie chart
#       9 plt.figure(figsize=(6, 6))  # Increased figure size for better visibility
# ---> 10 wedges, _, autotexts = plt.pie(
#      11     presenters_data,
#      12     colors=['#e67e22', '#2ecc71', '#f1c40f'],  # Customized color scheme
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, hatch, data)
#    2797         textprops=None, center=(0, 0), frame=False,
#    2798         rotatelabels=False, *, normalize=True, hatch=None, data=None):
# -> 2799     return gca().pie(
#    2800         x, explode=explode, labels=labels, colors=colors,
# ...

# %% [markdown]
# ## Gender Distribution (Season 3)

# %%
# Filter data for Season 1 and Ashneer's investments greater than 0
season_3_data = df[df['Season'] == 3]
Ashneer_investments = season_3_data[season_3_data['Ashneer Investment Amount'] > 0]

# Sum the number of presenters by gender for these filtered investments
presenters_data = Ashneer_investments[['Male Presenters', 'Female Presenters', 'Transgender Presenters']].sum()

# Plotting the pie chart
plt.figure(figsize=(6, 6))  # Increased figure size for better visibility
wedges, _, autotexts = plt.pie(
    presenters_data,
    colors=['#1abc9c', '#3498db', '#9b59b6'],  # Customized color scheme
    autopct='%1.2f%%',
    pctdistance=0.75,  # Pulls the percentage labels closer to the center
    shadow=True,  # Adds a shadow for a 3D effect
    wedgeprops={'edgecolor': 'black', 'linewidth': 1, 'antialiased': True}  # Enhances the wedge borders
)

# Increase font size for the percentage values
for autotext in autotexts:
    autotext.set_fontsize(14)  # Set font size to 14

# Adding a center circle to create a donut chart look
centre_circle = plt.Circle((0, 0), 0.50, fc='white')
plt.gca().add_artist(centre_circle)

# Adding a legend within the white circle area
plt.legend(wedges, ['Male', 'Female', 'Transgender'], title="Gender", loc="center", fontsize=12)

# Customizing the title
plt.title('Gender Distribution (Season 3)',
          fontsize=16, color='red', fontweight='bold', loc='center')

# Adjusting the layout for better spacing
plt.tight_layout()

# Displaying the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-44-1bc630c15daf> in <cell line: 10>()
#       8 # Plotting the pie chart
#       9 plt.figure(figsize=(6, 6))  # Increased figure size for better visibility
# ---> 10 wedges, _, autotexts = plt.pie(
#      11     presenters_data,
#      12     colors=['#1abc9c', '#3498db', '#9b59b6'],  # Customized color scheme
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, hatch, data)
#    2797         textprops=None, center=(0, 0), frame=False,
#    2798         rotatelabels=False, *, normalize=True, hatch=None, data=None):
# -> 2799     return gca().pie(
#    2800         x, explode=explode, labels=labels, colors=colors,
# ...

# %% [markdown]
# ## Gender Distribution (Season All)

# %%
# Filter data for Season 1 and Ashneer's investments greater than 0

Ashneer_investments = df[df['Ashneer Investment Amount'] > 0]

# Sum the number of presenters by gender for these filtered investments
presenters_data = Ashneer_investments[['Male Presenters', 'Female Presenters', 'Transgender Presenters']].sum()

# Plotting the pie chart
plt.figure(figsize=(6, 6))  # Increased figure size for better visibility
wedges, _, autotexts = plt.pie(
    presenters_data,
    colors=['#ff6f61', '#88b04b', '#b565a7'],  # Customized color scheme
    autopct='%1.2f%%',
    pctdistance=0.75,  # Pulls the percentage labels closer to the center
    shadow=True,  # Adds a shadow for a 3D effect
    wedgeprops={'edgecolor': 'black', 'linewidth': 1, 'antialiased': True}  # Enhances the wedge borders
)

# Increase font size for the percentage values
for autotext in autotexts:
    autotext.set_fontsize(14)  # Set font size to 14

# Adding a center circle to create a donut chart look
centre_circle = plt.Circle((0, 0), 0.50, fc='white')
plt.gca().add_artist(centre_circle)

# Adding a legend within the white circle area
plt.legend(wedges, ['Male', 'Female', 'Transgender'], title="Gender", loc="center", fontsize=12)

# Customizing the title
plt.title('Gender Distribution (Season All)',
          fontsize=16, color='red', fontweight='bold', loc='center')

# Adjusting the layout for better spacing
plt.tight_layout()

# Displaying the plot
plt.show()

# %% [markdown]
# ## Total Number of Presenters by Gender and Age Group - Shark Ashneer Grover

# %%
# Filter the data where Ashneer's investment amount is greater than 0 and for Season 1
Ashneer_investment_data = df[(df['Ashneer Investment Amount'] > 0) & (df['Season'])]

# Group by Age Group and sum the number of male, female, and transgender presenters
grouped_data = Ashneer_investment_data.groupby('Presenters Average Age')[['Male Presenters', 'Female Presenters', 'Transgender Presenters']].sum()

# Plotting the tri-bar chart
grouped_data.plot(kind='bar', figsize=(10, 6), color=['#1f77b4', '#ff7f0e', '#2ca02c'])

plt.title('Total Number of Presenters by Gender and Age Group - Shark Ashneer Grover')
plt.xlabel('Age Group')
plt.ylabel('Number of Presenters')
plt.xticks(rotation=0)
plt.legend(title='Presenter Gender')
plt.grid(axis='y', linestyle='--', linewidth=0.7)

# Display the plot
plt.show()
